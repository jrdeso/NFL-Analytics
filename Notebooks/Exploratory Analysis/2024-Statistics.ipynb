# %% [markdown]
# # 2024 NFL Statistics
#
# ## 1. Introduction
# - Get current statistics for the 2024 season on inividual player rankings and team statistics
#
# ## 2. Data Loading
# ### 2.1: Load database and notebook settings
# - Load necessary modules and nfl_fantasy.db (sqlite) into notebook
#
# ## 3. Player Statistics
# ### 3.1: Rushing Statistics
# ### 3.2: Receiving Statistics
# ### 3.3: Passing Statistics
# ### 3.4: Positional Fantasy Rankings
#
# ## 4. Team Statistics
# ### 4.1: Offensive Team Statistics
# ### 4.2: Defensive Team Statistics

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import seaborn as sns
import os

# %% [markdown]
# ## 2. Data Loading
# ### 2.1: Load database and notebook settings
# - Load necessary modules and nfl_fantasy.db (sqlite) into notebook

# %%
# %load_ext sql
conn = sqlite3.connect('..\\..\\nfl_fantasy.db')
cursor = conn.cursor()
# %sql sqlite:///C:\Users\Jrdes\Desktop\NFL\NFL-Analytics\nfl_fantasy.db

pd.set_option('display.max_rows', 100) # Increase pandas to display 100 rows max
pd.set_option('display.max_columns', 25)

# %% [markdown]
# ## 3. Player Statistics
# ### 3.1: Rushing Statistics

# %%
# %%sql db_player_rush_stats <<
#
# SELECT
#     pgs.PLAYER_NAME AS Player,
#     p.POSITION AS Position,
#     pgs.TEAM AS Team,
#     SUM(pgs.RUSHING_CARRIES) AS Carries,
#     SUM(pgs.RUSHING_RUSH_YARDS) AS Rushing_Yards,
#     SUM(pgs.RUSHING_RUSH_TOUCHDOWNS) AS Rushing_TDs,
#     ROUND(SUM(pgs.RUSHING_RUSH_YARDS * 1.0) / SUM(pgs.RUSHING_CARRIES), 2) AS YPC
# FROM
#     Player_Game_Stats pgs
#     INNER JOIN Game g on g.GAME_ID = pgs.GAME_ID
#     INNER JOIN Player p on p.PLAYER_ID = pgs.PLAYER_ID
# WHERE
#     g.GAME_TYPE = "Regular Season"
#     AND
#     g.SEASON_ID = "2024"
#     AND
#     pgs.RUSHING_CARRIES > 0
# GROUP BY
#     pgs.PLAYER_NAME,
#     pgs.TEAM
#
# ORDER BY
#     RUSHING_YARDS DESC;
# Out:
#  * sqlite:///C:\Users\Jrdes\Desktop\NFL\NFL-Analytics\nfl_fantasy.db
# Done.
# Returning data to local variable db_player_rush_stats

# %% [markdown]
# ### 3.2: Receiving Statistics

# %%
# %%sql db_player_rec_stats <<
#
# SELECT
#     pgs.PLAYER_NAME AS Player,
#     p.POSITION AS Position,
#     pgs.TEAM AS Team,
#     SUM(pgs.RECEIVING_TARGETS) AS Targets,
#     SUM(pgs.RECEIVING_RECEPTIONS) AS Receptions,
#     SUM(pgs.RECEIVING_REC_YARDS) AS Receiving_Yards,
#     SUM(pgs.RECEIVING_REC_TOUCHDOWNS) AS Receiving_TDs,
#     ROUND(SUM(pgs.RECEIVING_REC_YARDS * 1.0) / SUM(pgs.RECEIVING_RECEPTIONS), 2) AS YPC
# FROM
#     Player_Game_Stats pgs
#     INNER JOIN Game g on g.GAME_ID = pgs.GAME_ID
#     INNER JOIN Player p on p.PLAYER_ID = pgs.PLAYER_ID
# WHERE
#     g.GAME_TYPE = "Regular Season"
#     AND
#     g.SEASON_ID = "2024"
#     AND
#     pgs.RECEIVING_RECEPTIONS > 0
# GROUP BY
#     pgs.PLAYER_NAME,
#     pgs.TEAM
#
# ORDER BY
#     Receiving_Yards DESC;
# Out:
#  * sqlite:///C:\Users\Jrdes\Desktop\NFL\NFL-Analytics\nfl_fantasy.db
# Done.
# Returning data to local variable db_player_rec_stats

# %% [markdown]
# ### 3.3: Passing Statistics

# %%
# %%sql db_player_pass_stats <<
#
# SELECT
#     pgs.PLAYER_NAME AS Player,
#     p.POSITION AS Position,
#     pgs.TEAM AS Team,
#     SUM(pgs.PASSING_ATTEMPTS) AS Attempts,
#     SUM(pgs.PASSING_COMPLETIONS) AS Completions,
#     SUM(pgs.PASSING_YARDS) AS Passing_Yards,
#     SUM(pgs.PASSING_TOUCHDOWNS) AS Passing_TDs,
#     SUM(pgs.PASSING_INTERCEPTIONS) AS Interceptions,
#     ROUND(SUM(pgs.PASSING_COMPLETIONS * 1.0) / SUM(pgs.PASSING_ATTEMPTS), 2) AS Completion_Percentage
# FROM
#     Player_Game_Stats pgs
#     INNER JOIN Game g on g.GAME_ID = pgs.GAME_ID
#     INNER JOIN Player p on p.PLAYER_ID = pgs.PLAYER_ID
# WHERE
#     g.GAME_TYPE = "Regular Season"
#     AND
#     g.SEASON_ID = "2024"
#     AND
#     pgs.PASSING_ATTEMPTS > 0
# GROUP BY
#     pgs.PLAYER_NAME,
#     pgs.TEAM
#
# ORDER BY
#     Passing_TDs DESC;
# Out:
#  * sqlite:///C:\Users\Jrdes\Desktop\NFL\NFL-Analytics\nfl_fantasy.db
# Done.
# Returning data to local variable db_player_pass_stats

# %%
player_rush_stats_df = db_player_rush_stats.DataFrame()
player_rec_stats_df = db_player_rec_stats.DataFrame()
player_pass_stats_df = db_player_pass_stats.DataFrame()
player_pass_stats_df
# Out:
#                       Player Position Team  Attempts  Completions  \
# 0             Baker Mayfield       QB   TB       234          165
# 1                Jordan Love       QB   GB       179          110
# 2              Lamar Jackson       QB  BAL       198          135
# 3                 Joe Burrow       QB  CIN       226          159
# 4                 Josh Allen       QB  BUF       189          119
# 5                Sam Darnold       QB  MIN       164          109
# 6              Aaron Rodgers       QB  NYJ       256          158
# 7                C.J. Stroud       QB  HOU       229          152
# 8                 Jared Goff       QB  DET       174          128
# 9               Kirk Cousins       QB  ATL       242          162
# 10               Brock Purdy       QB   SF       216          138
# 11            Caleb Williams       QB  CHI       199          130
# 12              Kyler Murray       QB  ARI       196          130
# 13           Trevor Lawrence       QB  JAX       211          131
# 14              Dak Prescott       QB  DAL       224          142
# 15                Derek Carr       QB   NO       128           90
# 16                Geno Smith       QB  SEA       279          191
# 17               Andy Dalton       QB  CAR       160          106
# 18               Jalen Hurts       QB  PHI       171          116
# 19                Joe Flacco       QB  IND       108           71
# 20              Daniel Jones       QB  NYG       240          150
# 21            Jayden Daniels       QB  WSH       168          127
# 22            Justin Herbert       QB  LAC       164          107
# 23           Patrick Mahomes       QB   KC       187          127
# 24                    Bo Nix       QB  DEN       224          137
# 25            Deshaun Watson       QB  CLE       216          137
# 26                Drake Maye       QB   NE        78           50
# 27             Justin Fields       QB  PIT       160          106
# 28                Will Levis       QB  TEN       125           83
# 29           Gardner Minshew       QB   LV       174          114
# 30        Anthony Richardson       QB  IND       101           49
# 31          Matthew Stafford       QB  LAR       198          132
# 32           Aidan O'Connell       QB   LV        82           52
# 33           Jacoby Brissett       QB   NE       135           79
# 34              Malik Willis       QB   GB        34           25
# 35            Marcus Mariota       QB  WSH        26           19
# 36            Russell Wilson       QB  PIT        29           16
# 37            Tua Tagovailoa       QB  MIA        62           40
# 38         Amon-Ra St. Brown       WR  DET         1            1
# 39               Jake Haener       QB   NO        12            5
# 40            Jameis Winston       QB  CLE        12            6
# 41             Mason Rudolph       QB  TEN        57           34
# 42           Spencer Rattler       QB   NO        75           47
# 43             Tyler Huntley       QB  MIA        66           39
# 44              Tyrod Taylor       QB  NYJ         8            6
# 45           Adonai Mitchell       WR  IND         1            1
# 46               Bryce Young       QB  CAR        65           37
# 47               Cooper Rush       QB  DAL        14            9
# 48            Darnell Mooney       WR  ATL         1            0
# 49               Davis Mills       QB  HOU        13            7
# 50  Dorian Thompson-Robinson       QB  CLE        24           11
# 51                 Drew Lock       QB  NYG         8            3
# 52             Hendon Hooker       QB  DET         2            1
# 53        Jaxon Smith-Njigba       WR  SEA         1            1
# 54              Josh Johnson       QB  BAL         1            1
# 55             Kenny Pickett       QB  PHI         1            0
# 56                Kyle Allen       QB  PIT         1            1
# 57                 Mac Jones       QB  JAX         9            6
# 58              Malik Nabers       WR  NYG         1            0
# 59         Michael Penix Jr.       QB  ATL         1            1
# 60         Mitchell Trubisky       QB  BUF         3            2
# 61              Nick Mullens       QB  MIN         1            1
# 62           Skylar Thompson       QB  MIA        33           21
# 63              Stefon Diggs       WR  HOU         1            1
# 64           Taylor Heinicke       QB  LAC         2            2
# 65                 Tim Boyle       QB  MIA        26           15
# 66               Tutu Atwell       WR  LAR         1            0
#
#     Passing_Yards  Passing_TDs  Interceptions  Completion_Percentage
# 0            1859           18              7                   0.71
# 1            1351           15              8                   0.61
# 2            1810           15              2                   0.68
# 3            1759           14              2                   0.70
# 4            1483           12              0                   0.63
# 5            1370           12              5                   0.66
# 6            1663           10              7                   0.62
# 7            1663           10              4                   0.66
# 8            1610           10              4                   0.74
# 9            1830           10              7                   0.67
# 10           1841            9              7                   0.64
# 11           1317            9              5                   0.65
# 12           1331            9              3                   0.66
# 13           1527            9              3                   0.62
# 14           1602            8              6                   0.63
# 15            989            8              4                   0.70
# 16           1985            8              6                   0.68
# 17            989            7              6                   0.66
# 18           1308            7              4                   0.68
# 19            716            7              1                   0.66
# 20           1442            6              4                   0.63
# 21           1410            6              2                   0.76
# 22           1164            6              1                   0.65
# 23           1389            6              8                   0.68
# 24           1246            5              5                   0.61
# 25           1148            5              3                   0.63
# 26            541            5              2                   0.64
# 27           1106            5              1                   0.66
# 28            699            5              7                   0.66
# 29           1168            4              8                   0.66
# 30            783            3              6                   0.49
# 31           1392            3              4                   0.67
# 32            455            2              2                   0.63
# 33            696            2              1                   0.59
# 34            324            2              0                   0.74
# 35            203            2              0                   0.73
# 36            264            2              0                   0.55
# 37            483            2              3                   0.65
# 38              7            1              0                   1.00
# 39             55            1              0                   0.42
# 40             83            1              0                   0.50
# 41            300            1              1                   0.60
# 42            415            1              2                   0.63
# 43            377            1              1                   0.59
# 44             36            1              0                   0.75
# 45             24            0              0                   1.00
# 46            299            0              3                   0.57
# 47             52            0              1                   0.64
# 48              0            0              0                   0.00
# 49             79            0              0                   0.54
# 50             82            0              2                   0.46
# 51              6            0              0                   0.38
# 52             19            0              0                   0.50
# 53             35            0              0                   1.00
# 54              1            0              0                   1.00
# 55              0            0              0                   0.00
# 56             19            0              0                   1.00
# 57             28            0              0                   0.67
# 58              0            0              0                   0.00
# 59             14            0              0                   1.00
# 60              5            0              0                   0.67
# 61             24            0              0                   1.00
# 62            187            0              0                   0.64
# 63             13            0              0                   1.00
# 64             24            0              0                   1.00
# 65            153            0              0                   0.58
# 66              0            0              0                   0.00
